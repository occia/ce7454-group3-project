# %% [markdown]
# # SCRAPER Notebook
#
# Description:
# Retrieving relevant information from Instragram profiles

# %%
# ---------------------------------------------
# IMPORTS
# ---------------------------------------------

# External
import sys
# !{sys.executable} -m pip install -r requirements.txt

# Internal
from src.scraper.utils import init_url_manager
from src.scraper.utils import get_page
from src.scraper.utils import get_soup
from src.scraper.utils import get_image
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (4.8.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.25.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (6.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (1.16.4)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.7/site-packages (from beautifulsoup4->-r requirements.txt (line 1)) (1.9.4)

# %%
# ---------------------------------------------
# URL and GSHEET Load
# ---------------------------------------------
# base url for any kind of profile on third party data provider
url_base = "https://imgtagram.com/u/"

# user id for full url to request profile web page of third party provider
# TODO: insert gsheet request here
# TODO: users = getUsersByGSheet()
user_id = 'shutffuckup'

url = url_base + user_id

print(url)
# Out:
# https://imgtagram.com/u/shutffuckup

# %%
# ---------------------------------------------
# ESTABLISH CONNECTION
# ---------------------------------------------
# init url manager
url_manager = init_url_manager()

# get http source and convert to beautiful soup
res = get_page(url_manager, url)
soup = get_soup(res)

print(soup)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/boostrap.min.css" rel="stylesheet"/>
# <link href="/css/main.css?v=12254" rel="stylesheet"/>
# <title>View personal Instagram Profile @shutffuckup | Imgtagram</title>
# <meta content="Check latest photos and videos from @shutffuckup Queen born on June 28th￼♡ at Imgtagram Online Web Viewer and Downloader" name="description"/> <link href="https://imgtagram.com/" hreflang="en" rel="alternate">
# <!--<link rel="alternate" hreflang="ru" href="https://imgtagram.com/ru/" />-->
# <link href="/css/cookies.css" rel="stylesheet" type="text/css">
# <link href="/css/material-scrolltop.css?v=12254" rel="stylesheet"/>
# <script src="/js/cookieconsent.min.js"></script>
# <script>
#     window.addEventListener("load", function(){
#     window.cookieconsent.initialise({
#       "palette": {
#         "popup": {
#           "background": "#27253d"
#         },
#         "button": {
#           "background": "#ededf4"
#         }
#       },
#       "content": {
#         "message": "This website uses cookies to ensure you get the best experience on our website.",
#         "dismiss": "Got it!",
#         "link": "Learn more!",
#         "href": "https://imgtagram.com/policy"
#       }
#     })});
#     </script>
# <!-- <script src="js/adsbygoogle.js"></script> -->
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-1920565624943347",
#           enable_page_level_ads: true
#      });
# </script>
# <!-- <script src="js/adblock.js"></script> -->
# </link></link></head>
# <body>
# <header>
# <nav class="navbar navbar-expand-lg navbar-dark fixed-top">
# <div class="container">
# <a class="navbar-brand" href="/">Imgtagram</a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a class="nav-link" href="/">Home</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/contact">Contact US</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/policy" rel="nofollow">Privacy Policy &amp; Cookies</a>
# </li>
# <!--  <li class="nav-item dropdown">
#                         <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button" aria-haspopup="true" aria-expanded="false">Language</a>
#                         <div class="dropdown-menu">
#                             <a class="dropdown-item" href="/">English</a><a class="dropdown-item" href="/ru">Русский</a>                        </div>
#                     </li> -->
# </ul>
# </div>
# </div>
# </nav>
# <div class="fake-navbar"></div>
# </header>
# <section id="breads">
# <div class="container text-center">
# <p><a href="/">Imgtagram</a> » shutffuckup</p>
# </div>
# </section>
# <section id="u">
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5b623374de79ce92" type="text/javascript"></script>
# <div class="container">
# <div class="row info">
# <div class="col-lg-2 col-md-4 col-sm-6 offset-sm-3 col-8 offset-2 offset-md-4 offset-lg-0">
# <img alt="Misha🇨🇦 Queen born on June 28th￼♡ by @shutffuckup - Imgtagram" class="icon" src="https://scontent-dub4-1.cdninstagram.com/vp/28b0183f1717b96bc55ae61ee310e062/5E434405/t51.2885-19/73343201_2338092192968557_2486256984542674944_n.jpg?_nc_ht=scontent-dub4-1.cdninstagram.com" title="Misha🇨🇦 Queen born on June 28th￼♡ by @shutffuckup - Imgtagram"/>
# </div>
# <div class="col-lg-4 col-md-12 col-sm-12 offset-sm-0 col-12 offset-0 offset-md-0 paddz">
# <div class="text-block">
# <h1>Misha🇨🇦 </h1>
# <h3>@shutffuckup</h3>
# <p class="descp">Queen born on June 28th￼♡</p>
# <p style="font-size: 12px; margin-top: 10px;"><a href="http://Canada.MF/" rel="nofollow">http://Canada.MF/</a></p>
# </div>
# <div class="but col-xl-7 col-lg-8 col-md-12 offset-lg-0 col-sm-12 but-div d-lg-none d-flex">
# <div class="col-lg-12 col-md-8 col-8 a-d-div" hidden="">
# <div class="a-div col-12">
# <a href="/story/shutffuckup">Story</a>
# </div>
# </div>
# <div class="col-lg-12 col-md-8 col-8 a-d-div" hidden="">
# <div class="a-div col-12">
# <a href="/igtv/shutffuckup">IGTV</a>
# </div>
# </div>
# <div class="col-lg-12 col-md-8 col-8 a-d-div">
# <div class="a-div col-12">
# <a href="/stats/shutffuckup">Stats</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xl-5 col-lg-6 offset-xl-1 col-md-12 offset-lg-0 col-sm-12 but-div">
# <div class="buts col-lg-12 col-md-8 col-8">
# <div class="click-block col-lg-4 col-12 selected">
# <a href="/u/shutffuckup">
#                         6 Photos                    </a>
# </div>
# <div class="click-block col-lg-4 col-12">
# <a href="/following/shutffuckup">
#                         129 Following                    </a>
# </div>
# <div class="click-block col-lg-4 col-12">
# <a href="/followers/shutffuckup">
#                       43 Followers                    </a>
# </div>
# </div>
# <div class="col-lg-12 col-md-8 share-row">
# <div class="share">
# <div class="addthis_inline_share_toolbox"></div>
# </div>
# </div>
# </div>
# <div class="col-lg-4 offset-lg-2 paddz d-lg-block d-none">
# <div class="but col-xl-7 col-lg-8 col-md-12 offset-lg-0 col-sm-12 but-div">
# <div class="col-lg-12 col-md-8 col-8 a-d-div" hidden="">
# <div class="a-div col-12">
# <a href="/story/shutffuckup">Story</a>
# </div>
# </div>
# <div class="col-lg-12 col-md-8 col-8 a-d-div" hidden="">
# <div class="a-div col-12">
# <a href="/igtv/shutffuckup">IGTV</a>
# </div>
# </div>
# <div class="col-lg-12 col-md-8 col-8 a-d-div">
# <div class="a-div col-12">
# <a href="/stats/shutffuckup">Stats</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row mt-3 mb-3">
# <div class="col-lg-12">
# <p><b>Instagram account <b>shutffuckup</b>  short summary</b><br/><br/> You are browsing a <b>shutffuckup</b>  profile of <b>Misha🇨🇦</b>  at Imgtagram. The <b>shutffuckup</b>  ID of <b>Misha🇨🇦</b>  instagram account is <i><b>18327952352</b> </i>.The <b>shutffuckup</b>  has private account type. Instagram account <b>shutffuckup</b>  of <b>Misha🇨🇦</b>  is not verified by Instagram. Regular Instagram profile like others. User <b>shutffuckup</b>  has posted <i><b>6</b> </i> media under <b>Misha🇨🇦</b>  name. The <b>shutffuckup</b>  account owner under name <b>Misha🇨🇦</b>  follows <i><b>129</b> </i> instagram users. <b>Misha🇨🇦</b>  has total number of followers <i><b>43</b> </i> at the time you are viewing this page. The <b>shutffuckup</b>  account owner under name <b>Misha🇨🇦</b>  follows <i><b>129</b> </i> instagram users. There are no IGTV posted by <b>Misha🇨🇦</b>  at <b>shutffuckup</b>  account. Come back later to <b>Misha🇨🇦</b>  and look around again. No media with hashtags were found at <b>shutffuckup</b>  profile. There are favourite hashtags of <b>shutffuckup</b>  profile. <b>shutffuckup</b>  under name <b>Misha🇨🇦</b>  has <i><b>6</b> </i> favourite hashtags to follow. All instagram content is available 24/7 at Imgtagram.</p>
# </div>
# </div>
# </div>
# <div class="ad-9 ad" id="ad">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Insta horizont adaptive -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1920565624943347" data-ad-format="auto" data-ad-slot="3678517296" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# <div class="clear"></div><div class="ad-15 ad" id="ad">
# <div class="d-block">
# <script>
# var h12precont = 'h12c_300x250_' + Math.floor(Math.random()*1000000);
# document.write('<div id="' + h12precont + '"></div>');
# (h12_adarray = window.h12_adarray || []).push({"adcontainer":h12precont,"placement":"e51e827b2186cd2d83665d65cda9e108","size":"300x250","type":"standard","width":"300","height":"250","name":""});
# </script>
# <script async="" src="//tags.h12-media.com/load.js"></script>
# </div>
# </div>
# <div class="clear"></div><div class="container">
# <div class="row on-section">
# <div class="photo-section">
# <h3 style="color: black; margin-top: 30px;">Private user</h3> </div>
# </div>
# </div> </section>
# <footer>
# <div class="container">
# <div class="row">
# <div class="flexing-box col-lg-12">
# <a href="/contact">Contact US</a>
# <a href="/policy" rel="nofollow">Privacy Policy &amp; Cookies</a>
# </div>
# </div>
# <div class="row">
# <div class="flexing-box col-lg-12">
# <p>Imgtagram © 2019. All Right Reserved.</p>
# </div>
# </div>
# <div class="row">
# <div class="flexing-box col-lg-12">
# <p>This site uses the Instagram API, but is not endorsed or certified by Instagram. All InstagramTM logos and trademarks displayed on this application are property of Instagram</p>
# </div>
# </div>
# </div>
# </footer>
# <div class="modal" id="admodal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">AD Blocking</h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <p>You use an ad blocker, so we reproduced all the images on the site.</p>
# </div>
# </div>
# </div>
# </div>
# <script defer="" src="/js/fall.js"></script>
# <!-- Global Site Tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-123028422-1"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'UA-123036116-1');
#     </script>
# <script src="/js/intersection-observer.min.js"></script>
# <script src="/js/lazyload.min.js"></script>
# <script src="/js/jquery.min.js"></script>
# <script src="/js/bootstrap.min.js"></script>
# <script src="/js/forms.js?v=12254"></script>
# <input id="add" type="hidden" value="18327952352"/>
# <input id="lang" type="hidden" value="en"/>
# <input id="page" type="hidden" value="u"/>
# <input id="scroll" type="hidden" value="200"/><script src="/js/load.js?v=12254"></script> <script>
#         $( document ).ready(function(){
#         if($(document).height() <= $(window).height())
#         $("footer").addClass("fixed-bottom");
#         $(window).resize(function(){
#             if($(document).height() <= $(window).height())
#             $("footer").addClass("fixed-bottom");
#             else if($(document).height() > $(window).height())
#             $("footer").removeClass("fixed-bottom");
#         });
#         $('html').attr('lang','en');
#         });
#     </script>
# <script>
#      /*     function adBlockDetected() {
#             $('img,video,svg,i').css('transform','rotate(180deg)');
#             $('#admodal').modal('toggle');
#         }
#         if(typeof fuckAdBlock !== 'undefined' || typeof FuckAdBlock !== 'undefined') {
#             adBlockDetected();
#         } else {
#           var importFAB = document.createElement('script');
#             importFAB.onload = function() {
#                 fuckAdBlock.onDetected(adBlockDetected)
#             };
#             importFAB.onerror = function() {
#                 adBlockDetected();
#             };
#             importFAB.integrity = 'sha256-xjwKUY/NgkPjZZBOtOxRYtK20GaqTwUCf7WYCJ1z69w=';
#             importFAB.crossOrigin = 'anonymous';
#             importFAB.src = 'https://cdnjs.cloudflare.com/ajax/libs/fuckadblock/3.2.1/fuckadblock.min.js';
#             document.head.appendChild(importFAB);
#         } */
#         var lazyLoadInstance = new LazyLoad({
# 		    elements_selector: ".lazy"
#
# 		});
#     </script>
# <!-- material-scrolltop button -->
# <button class="material-scrolltop" type="button"></button>
# <!-- material-scrolltop plugin -->
# <script src="/js/material-scrolltop.js"></script>
# <!-- Initialize material-scrolltop with (minimal) -->
# <script>
#         $('body').materialScrollTop();
#     </script>
# </body>
# </html>

# %%
# ---------------------------------------------
# GET PROFILE PICTURE
# ---------------------------------------------
# get div container for profile picture
pic_url = soup.find('img', {'class': 'icon'})['src']
img_res = get_page(url_manager, pic_url)
img = get_image(img_res)
img.show()

# %%
# ---------------------------------------------
# GET PERSONAL INFORMATION
# ---------------------------------------------
# get div container for personal information
pers_container = soup.find('div', {'class': 'text-block'})
name = pers_container.find('h1').text
bio = pers_container.find('p', {'class': 'descp'}).text

print(name)
print(bio)
# Out:
# Misha🇨🇦
# Queen born on June 28th￼♡
